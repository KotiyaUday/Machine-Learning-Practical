# %% [markdown]
# # PRACTICAL-9
# # Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of given company between two specific dates.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/national-stock-exchange-time-series/infy_stock.csv')
df
# Out:
#            Date Symbol Series  Prev Close     Open     High     Low     Last  \
# 0    2015-01-01   INFY     EQ     1972.55  1968.95  1982.00  1956.9  1971.00
# 1    2015-01-02   INFY     EQ     1974.40  1972.00  2019.05  1972.0  2017.95
# 2    2015-01-05   INFY     EQ     2013.20  2009.90  2030.00  1977.5  1996.00
# 3    2015-01-06   INFY     EQ     1995.90  1980.00  1985.00  1934.1  1965.10
# 4    2015-01-07   INFY     EQ     1954.20  1965.00  1974.75  1950.0  1966.05
# ..          ...    ...    ...         ...      ...      ...     ...      ...
# 243  2015-12-24   INFY     EQ     1100.85  1102.05  1104.45  1090.1  1095.80
# 244  2015-12-28   INFY     EQ     1096.35  1090.00  1110.00  1090.0  1103.80
# 245  2015-12-29   INFY     EQ     1104.75  1101.25  1110.00  1097.3  1103.00
# 246  2015-12-30   INFY     EQ     1104.70  1101.10  1106.60  1083.0  1088.00
# 247  2015-12-31   INFY     EQ     1086.30  1090.15  1109.95  1087.0  1107.00
#
# ...

# %%
df = df.set_index(df['Date'])
df = df['2015-01-01':'2015-01-30']

up = df[df['Close'] >= df['Open']]
down = df[df['Open'] > df['Close']]

plt.figure(figsize=(10,5))


plt.bar(x=up.index,height=up.Close-up.Open,bottom=up['Open'],width=0.3,color='green')
plt.bar(x=up.index,height=up.High-up.Low,bottom=up['Low'],width=0.05,color='green')

plt.bar(x=down.index,height=down.Close-down.Open,bottom=down['Close'],width=0.3,color='red')
plt.bar(x=down.index,height=down.High-down.Low,bottom=down['Low'],width=0.05,color='red')
plt.xticks(rotation=45, ha='right')
plt.title("Candlestick Chart",fontsize=22)
plt.xlabel("Dates",fontsize=18)
plt.ylabel("Prices",fontsize=18)
plt.rcParams['figure.facecolor'] = 'grey'
plt.rcParams['axes.facecolor'] = 'black'

plt.show()
