# %% [markdown]
# # PRACTICAL 8
# # Write a Pandas program to create a line plot of the opening, closing stock prices of given company between two specific dates.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/infosys-stock-price-till-april2023/infosys1.csv')
df
# Out:
#             Date      Open      High       Low     Close        Volume
# 0     2023-04-28  15.26000  15.55000  15.26000  15.54000  1.166694e+07
# 1     2023-04-27  15.08000  15.34000  15.08000  15.31000  1.160640e+07
# 2     2023-04-26  14.83000  14.95000  14.78000  14.85000  1.118175e+07
# 3     2023-04-25  14.88000  14.88000  14.78000  14.79000  1.470026e+07
# 4     2023-04-24  14.82000  14.86000  14.71200  14.82000  1.175196e+07
# ...          ...       ...       ...       ...       ...           ...
# 1084  2019-01-08   9.02869   9.05226   8.93327   8.96420  1.021407e+07
# 1085  2019-01-07   8.91913   9.02006   8.88213   8.92865  8.409867e+06
# 1086  2019-01-04   8.75342   8.93799   8.73506   8.85454  7.742369e+06
# 1087  2019-01-03   8.78100   8.81753   8.70747   8.70747  1.022845e+07
# 1088  2019-01-02   8.73506   8.94731   8.70747   8.83598  1.067872e+07
#
# [1089 rows x 6 columns]

# %%
df = df.sort_values(by=['Date'])
df = df.set_index(df['Date'])
Data = df['2019-01-02':'2019-07-31':10]
Dates = Data['Date']
Opening = Data['Open']
Closing = Data['Close']
plt.figure(figsize=(20,7))
plt.title("Stock Market")
plt.plot(Dates,Opening,label='Open',marker='o')
plt.plot(Dates,Closing,label='Close',marker='o')
plt.xlabel('Dates')
plt.ylabel('Price')
plt.grid()
plt.legend()
plt.show()
