# %% [markdown]
# # PRACTICAL 10
# # Write a Pandas program to implement following operation :

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/titanic-dataset/Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### **To find and drop the missing values from the given dataset**

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_new = df.dropna()

# %%
df_new.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### **To remove the duplicates from the given dataset**

# %% [markdown]
# #### *Adding Duplicates*

# %%
df.loc[891] = [4,1,1,'Futrelle, Mrs. Jacques Heath (Lily May Peel)','female',35.0,1,0,113803,53.1000,'C123','S']
df.loc[892] = [2,1,1,'Cumings, Mrs. John Bradley (Florence Briggs Th...','female',38.0,1,0,'PC 17599',71.2833,'C85','C']

df.loc[893] = [4,1,1,'Futrelle, Mrs. Jacques Heath (Lily May Peel)','female',35.0,1,0,113803,53.1000,'C123','S']
df.loc[894] = [2,1,1,'Cumings, Mrs. John Bradley (Florence Briggs Th...','female',38.0,1,0,'PC 17599',71.2833,'C85','C']

df.loc[895] = [4,1,1,'Futrelle, Mrs. Jacques Heath (Lily May Peel)','female',35.0,1,0,113803,53.1000,'C123','S']
df.loc[896] = [2,1,1,'Cumings, Mrs. John Bradley (Florence Briggs Th...','female',38.0,1,0,'PC 17599',71.2833,'C85','C']

df.loc[897] = [4,1,1,'Futrelle, Mrs. Jacques Heath (Lily May Peel)','female',35.0,1,0,113803,53.1000,'C123','S']
df.loc[898] = [2,1,1,'Cumings, Mrs. John Bradley (Florence Briggs Th...','female',38.0,1,0,'PC 17599',71.2833,'C85','C']

df.loc[899] = [4,1,1,'Futrelle, Mrs. Jacques Heath (Lily May Peel)','female',35.0,1,0,113803,53.1000,'C123','S']
df.loc[900] = [2,1,1,'Cumings, Mrs. John Bradley (Florence Briggs Th...','female',38.0,1,0,'PC 17599',71.2833,'C85','C']

df.loc[901] = [4,1,1,'Futrelle, Mrs. Jacques Heath (Lily May Peel)','female',35.0,1,0,113803,53.1000,'C123','S']
df.loc[902] = [2,1,1,'Cumings, Mrs. John Bradley (Florence Briggs Th...','female',38.0,1,0,'PC 17599',71.2833,'C85','C']

df.loc[903] = [4,1,1,'Futrelle, Mrs. Jacques Heath (Lily May Peel)','female',35.0,1,0,113803,53.1000,'C123','S']
df.loc[904] = [2,1,1,'Cumings, Mrs. John Bradley (Florence Briggs Th...','female',38.0,1,0,'PC 17599',71.2833,'C85','C']

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0
